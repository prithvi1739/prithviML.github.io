# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods =  1000), columns = ['Values'])
df
# Out:
#               Values
# 2019-06-07  1.621710
# 2019-06-08 -0.396869
# 2019-06-09  0.604744
# 2019-06-10 -1.212896
# 2019-06-11  0.428998
# ...              ...
# 2022-02-26 -0.836972
# 2022-02-27 -1.812482
# 2022-02-28  1.021672
# 2022-03-01 -0.309429
# 2022-03-02  0.018029
#
# [1000 rows x 1 columns]

# %%
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
ts.head()
# Out:
# 2019-06-07    0.961498
# 2019-06-08    0.811403
# 2019-06-09    0.123023
# 2019-06-10    0.663933
# 2019-06-11   -0.458276
# Freq: D, dtype: float64

# %%
ts.head().plot()

# %%
ts.plot()

# %%
ts = ts.cumsum()
ts.plot()

# %%
ts.plot(figsize=(5,5))

# %%
ts.plot(figsize=(50,5))

# %%
ts.plot(figsize=(50,50))

# %%
df.plot()

# %%
df.cumsum().plot()

# %%
plt.plot(ts)

# %% [markdown]
# ### this is matplotlib plot...whatever we have seen till now is nothing but pandas plot basically...

# %%
iris = sns.load_dataset('iris')
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
i = iris.head(10)
i
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
ax = iris.plot(figsize=(15,8), title='Iris Dataset')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
 ax = iris.plot(figsize=(15,8), title='Iris Dataset', kind = 'bar')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(0, 0.5, 'Y Axis')

# %% [markdown]
# ### Not at all a good idea.

# %% [markdown]
# ### so, I can do the following...

# %%
a = iris.drop('species',axis = 1)
a.iloc[0].plot(kind = 'bar')

# %% [markdown]
# ### or we can try to call the bar as function.

# %%
a.iloc[0].plot.bar()

# %% [markdown]
# ## one more data set Im going to load directly from the Seaborn library...
# ## you can also download the csv data file from the seaborn github repository or you can directly load it from there.

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.pclass.plot(kind = 'bar')

# %%
df = pd.DataFrame(randn(10, 4),columns = ['a','b','c','d'])
df.head(10)
# Out:
#           a         b         c         d
# 0  0.684458 -0.307492 -1.190588 -1.133735
# 1 -0.431777 -0.223701  1.506452 -1.014307
# 2  1.957715  1.311204  0.196861 -0.530601
# 3  1.280670 -0.008796 -2.468235  0.296610
# 4  0.979234 -0.874045  1.763572  1.655189
# 5 -0.554704  0.366713 -0.966578  0.738298
# 6  0.547477  0.762711  0.438425 -0.809288
# 7 -0.299974  0.286173 -0.752049 -0.046921
# 8 -1.227640  0.154772 -0.554769 -0.326209
# 9  1.136069 -0.656935  1.668468  0.556413

# %%
df.plot.bar()

# %%
df.plot.barh()

# %% [markdown]
# For horizontal bar graph

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.plot(kind = 'hist' )

# %%
iris.sepal_length.plot('hist')
# Out:
# C:\Users\lahari\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='hist')` instead of `Series.plot('hist',)`.
#   """Entry point for launching an IPython kernel.

# %%
iris.plot(kind = 'hist' ,stacked = False , bins = 100)

# %%
iris.plot(kind = 'hist' ,stacked = False , bins = 100 , orientation ='horizontal')

# %%
iris.sepal_width.diff().plot(kind = 'hist',stacked = True,bins = 50)

# %%
df = iris.drop(['species'], axis = 1)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
df = iris.drop(['species'], axis = 1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color = 'r', alpha = 0.9, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000143C0636848>,
# ...
#       dtype=object)

# %%
iris.plot(kind = 'scatter',x = 'sepal_length', y = 'petal_length', title = 'Scatter plot')

# %%
iris.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width')

# %%
iris.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s = 500)

# %%
df.plot.hexbin(x = 'sepal_length', y = 'petal_length', gridsize = 5, C = 'sepal_width')

# %%
d = df.iloc[0]
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize = (5,5))

# %%
d = df.head(3).T
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots = True, figsize = (20, 20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000143C124C188>,
# ...
#       dtype=object)

# %%
d.plot.pie(subplots = True, figsize = (20, 20), fontsize = 26, autopct = '%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000143C14BBF48>,
# ...
#       dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index = ['a','b','c', 'd','e'], name = 'Pie Plot')
series.plot.pie()

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, figsize= (8,8), diagonal='kde', color = 'r')
plt.show()
